# %%
! pip install torch transformers unsloth langchain faiss-gpu sentence-transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 kB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.6/136.6 kB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 35.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 12.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 18.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 396.2/396.2 kB 31.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.7/150.7 kB 11.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 11.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.7 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain_community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 22.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 3.0 MB/s eta 0:00:00
# ...

# %%
# !pip install xformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.1/779.1 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 27.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 88.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 48.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 9.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 14.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 8.2 MB/s eta 0:00:00
# ...

# %%
# %%capture
# Installs Unsloth, Xformers (Flash Attention) and all other packages!
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps "xformers<0.0.27" "trl<0.9.0" peft accelerate bitsandbytes

# %%
import os

from unsloth import FastLanguageModel
from transformers import pipeline
from langchain.llms import HuggingFacePipeline
from langchain.chains import ConversationalRetrievalChain
from langchain.vectorstores import FAISS
from langchain.embeddings import HuggingFaceEmbeddings
from langchain_community.document_loaders.csv_loader import CSVLoader
from langchain.text_splitter import CharacterTextSplitter
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-baa5f2a228c9> in <cell line: 3>()
#       1 import os
#       2
# ----> 3 from unsloth import FastLanguageModel
#       4 from transformers import pipeline
#       5 from langchain.llms import HuggingFacePipeline
#
# /usr/local/lib/python3.10/dist-packages/unsloth/__init__.py in <module>
#     101 import bitsandbytes as bnb
#     102
# --> 103 import triton
#     104 libcuda_dirs = lambda: None
#     105 if Version(triton.__version__) >= Version("3.0.0"):
#
# ModuleNotFoundError: No module named 'triton'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ...

# %%
import torch

def clear_gpu_cache():
    torch.cuda.empty_cache()
    torch.cuda.ipc_collect()
    print("GPU cache cleared.")

clear_gpu_cache()

# %%
def generate_response(prompt):
    try:
        inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
        outputs = model.generate(**inputs, max_length=512)
        response = tokenizer.decode(outputs[0], skip_special_tokens=True)
        return response
    except Exception as e:
        return f"An error occurred: {str(e)}"

# %%
# Prepare the model for inference
FastLanguageModel.for_inference(model)

# Testing the fine-tuned model with a sample question
input_text = "What are the key ESG reporting standards companies should follow?"
inputs = tokenizer(input_text, return_tensors="pt").to(model.device)
outputs = model.generate(**inputs, max_length=512)
response = tokenizer.decode(outputs[0], skip_special_tokens=True)

# Output the result
print("User:", input_text)
print("Bot:", response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-65c1590f3e02> in <cell line: 2>()
#       1 # Prepare the model for inference
# ----> 2 FastLanguageModel.for_inference(model)
#       3
#       4 # Testing the fine-tuned model with a sample question
#       5 input_text = "What are the key ESG reporting standards companies should follow?"
#
# NameError: name 'model' is not defined

# %% [markdown]
# # Gradio Interface

# %%
pip install gradio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 88.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.7/318.7 kB 27.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 113.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 12.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tomlkit
#     Found existing installation: tomlkit 0.13.2
#     Uninstalling tomlkit-0.13.2:
#       Successfully uninstalled tomlkit-0.13.2
# ...

# %%
# Prepare the model for inference
FastLanguageModel.for_inference(model)

# Define a sample query
sample_query = "How does a company's ESG performance impact its financial performance?"

# Generate a response using the pipeline
response = text_generation_pipeline(sample_query)[0]['generated_text']

# Print the model's response
print(f"Query: {sample_query}")
print(f"Response: {response}")
# Out:
# Query: How does a company's ESG performance impact its financial performance?
# Response:  This question has been the subject of much debate and research. While some studies have found that companies with strong environmental, social, and governance (ESG) practices tend to outperform their peers financially, other studies have reached different conclusions.
# One study by Harvard Business School professor George Serafeim found that there is no clear relationship between a firm’s sustainability ratings and its stock market returns or accounting profitability. However, he did find evidence suggesting that firms’ sustainability efforts may be associated with higher levels of innovation in products and processes as well as lower costs for capital expenditures such as energy efficiency improvements.
# ...

# %%
input_text = "How does a company's ESG performance impact its financial performance?"

# Tokenize the input text
inputs = tokenizer(input_text, return_tensors="pt").to(model.device)

# Generate a response using the model
outputs = model.generate(**inputs, max_length=1024)

# Decode and print the model's response
response = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(f"Query: {input_text}")
print(f"Response: {response}")
# Out:
# Query: How does a company's ESG performance impact its financial performance?
# Response: How does a company's ESG performance impact its financial performance? What role does ESG play in investment decisions? What are the factors that drive ESG performance? These are the questions that the CFA Institute ESG research initiative aims to answer. The ESG research initiative is a global, collaborative effort to advance research on the relationship between ESG performance and financial performance. The initiative is led by a team of researchers from the CFA Institute, and it includes contributions from a wide range of experts in the field. The research initiative has produced a number of important findings, which are summarized below.
# The relationship between ESG performance and financial performance
# ...

# %%
# !pip install triton
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 6.4 MB/s eta 0:00:00
# ...

# %%
import gradio as gr
from transformers import pipeline
from unsloth import FastLanguageModel
from langchain.llms import HuggingFacePipeline
from langchain.chains import ConversationalRetrievalChain
from langchain.vectorstores import FAISS
from langchain.embeddings import HuggingFaceEmbeddings
from langchain_community.document_loaders.csv_loader import CSVLoader
from langchain.text_splitter import CharacterTextSplitter
import os

# Set your Hugging Face token in the environment variables
os.environ["HF_TOKEN"] = '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'

# Load your fine-tuned model and tokenizer using Unsloth
model_name = "AchrafGhribi31/llama3-esg-8b-merged-4bit_finalchat"
tokenizer_name = model_name  # Use the same name for the tokenizer

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name=model_name,
    max_seq_length=1024,
    load_in_4bit=True,
    token=os.environ.get("HF_TOKEN")
)

# Prepare the model for inference
FastLanguageModel.for_inference(model)

# Create the text generation pipeline using your fine-tuned model
text_generation_pipeline = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    eos_token_id=tokenizer.eos_token_id,
    pad_token_id=tokenizer.eos_token_id,
    repetition_penalty=1.1,
    return_full_text=False,
    max_new_tokens=200,
    temperature=0.3,  # Lowered temperature for more deterministic output
    do_sample=False,  # Disabled sampling for more deterministic output
    top_k=30,  # Reduced top_k for more focused generation
    top_p=0.8
)


# Create the HuggingFacePipeline LLM
fine_tuned_llm = HuggingFacePipeline(pipeline=text_generation_pipeline)

# Load and process the CSV file
dataset_path = '/content/CompaniesDataESG.csv'  # Replace with your actual file path
loader = CSVLoader(file_path=dataset_path)
data = loader.load()

# Split the documents into smaller chunks
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
chunked_docs = text_splitter.split_documents(data)

# Create embeddings and build the FAISS index
embeddings = HuggingFaceEmbeddings(model_name='sentence-transformers/all-mpnet-base-v2')
db = FAISS.from_documents(chunked_docs, embeddings)

# Connect query to FAISS index using a retriever
retriever = db.as_retriever(
    search_type="similarity",
    search_kwargs={'k': 4}
)

# Create the Conversational Retrieval Chain
qa_chain = ConversationalRetrievalChain.from_llm(
    llm=fine_tuned_llm,
    retriever=retriever,
    return_source_documents=True
)

# Initialize the chat history
chat_history = []
feedback_log = []  # Store feedback here

# Define the chatbot function
def chatbot(query, chat_history=[]):
    global qa_chain, tokenizer, model

    try:
        # Determine if the query is general or company-specific
        company_keywords = ["company", "performance", "ESG risk", "rating", "sector", "employees",
                            "decarbonization", "target", "turnover", "Name", "Ticker", "Sector"]

        if any(keyword.lower() in query.lower() for keyword in company_keywords):
            # Company-specific query, use the retriever
            result = qa_chain.invoke({'question': query, 'chat_history': chat_history})
            answer = result['answer']
        else:
            # General ESG question, use the fine-tuned model directly
            inputs = tokenizer(query, return_tensors="pt").to(model.device)
            outputs = model.generate(**inputs, max_length=512)
            answer = tokenizer.decode(outputs[0], skip_special_tokens=True)

        # Append the question and answer to the chat history
        chat_history.append((query, answer))

        # Prepare the history for display in the Gradio chat interface
        chat_history_display = [(f"User: {q}", f"Bot: {a}") for q, a in chat_history]

        return chat_history_display, chat_history

    except Exception as e:
        return [("Error", f"An error occurred: {str(e)}")], chat_history

# Function to reset the chat history
def reset_chat():
    return [], []

# Function to handle feedback
def give_feedback(feedback, chat_history):
    feedback_log.append((chat_history[-1], feedback))
    print(f"Received feedback: {feedback} for the response: {chat_history[-1]}")
    return "Feedback recorded!"

# Define the Gradio chat interface
with gr.Blocks() as iface:
    gr.Markdown("# ESG Chatbot")

    with gr.Row():
        with gr.Column(scale=3):
            chatbox = gr.Chatbot(label="ESG Chatbot")

            with gr.Row():
                good_feedback = gr.Button("👍 Good")
                bad_feedback = gr.Button("👎 Bad")

        with gr.Column(scale=1):
            textbox = gr.Textbox(label="Type your query here:")
            submit_button = gr.Button("Submit")
            reset_button = gr.Button("Start New Conversation")

    # Function to handle button click and update chatbox
    def on_submit(query, history):
        chat_history_display, updated_history = chatbot(query, history)
        return chat_history_display, updated_history

    # Connect functions to buttons
    submit_button.click(on_submit, inputs=[textbox, chatbox], outputs=[chatbox, chatbox])
    textbox.submit(on_submit, inputs=[textbox, chatbox], outputs=[chatbox, chatbox])
    reset_button.click(reset_chat, outputs=[chatbox, textbox])
    good_feedback.click(lambda history: give_feedback("Good", history), inputs=[chatbox], outputs=None)
    bad_feedback.click(lambda history: give_feedback("Bad", history), inputs=[chatbox], outputs=None)

# Launch the interface
iface.launch()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-ce877bffe574> in <cell line: 3>()
#       1 import gradio as gr
#       2 from transformers import pipeline
# ----> 3 from unsloth import FastLanguageModel
#       4 from langchain.llms import HuggingFacePipeline
#       5 from langchain.chains import ConversationalRetrievalChain
#
# /usr/local/lib/python3.10/dist-packages/unsloth/__init__.py in <module>
#     101 import bitsandbytes as bnb
#     102
# --> 103 import triton
#     104 libcuda_dirs = lambda: None
#     105 if Version(triton.__version__) >= Version("3.0.0"):
#
# ModuleNotFoundError: No module named 'triton'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# ...

# %%
import gradio as gr
from transformers import pipeline
from unsloth import FastLanguageModel
from langchain.llms import HuggingFacePipeline
from langchain.chains import ConversationalRetrievalChain
from langchain.vectorstores import FAISS
from langchain.embeddings import HuggingFaceEmbeddings
from langchain_community.document_loaders.csv_loader import CSVLoader
from langchain.text_splitter import CharacterTextSplitter
import os

# Set your Hugging Face token in the environment variables
os.environ["HF_TOKEN"] = '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'
# Load your fine-tuned model and tokenizer using Unsloth
model_name = "AchrafGhribi31/llama3-esg-8b-merged-4bit_finalchat"
tokenizer_name = model_name  # Use the same name for the tokenizer

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name=model_name,
    max_seq_length=1024,
    load_in_4bit=True,
    token=os.environ.get("HF_TOKEN")
)

# Prepare the model for inference
FastLanguageModel.for_inference(model)

# Create the text generation pipeline using your fine-tuned model
text_generation_pipeline = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    eos_token_id=tokenizer.eos_token_id,
    pad_token_id=tokenizer.eos_token_id,
    repetition_penalty=1.2,
    return_full_text=False,
    max_new_tokens=200,
    temperature=0.5,  # Lowered temperature for more deterministic output
    do_sample=False,  # Disabled sampling for more deterministic output
    top_k=50,  # Reduced top_k for more focused generation
    top_p=0.8
)


# Create the HuggingFacePipeline LLM
fine_tuned_llm = HuggingFacePipeline(pipeline=text_generation_pipeline)

# Load and process the CSV file
dataset_path = '/content/CompaniesDataESG.csv'  # Replace with your actual file path
loader = CSVLoader(file_path=dataset_path)
data = loader.load()

# Split the documents into smaller chunks
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
chunked_docs = text_splitter.split_documents(data)

# Create embeddings and build the FAISS index
embeddings = HuggingFaceEmbeddings(model_name='sentence-transformers/all-mpnet-base-v2')
db = FAISS.from_documents(chunked_docs, embeddings)

# Connect query to FAISS index using a retriever
retriever = db.as_retriever(
    search_type="similarity",
    search_kwargs={'k': 4}
)

# Create the Conversational Retrieval Chain
qa_chain = ConversationalRetrievalChain.from_llm(
    llm=fine_tuned_llm,
    retriever=retriever,
    return_source_documents=True
)

# Initialize the chat history
chat_history = []
feedback_log = []  # Store feedback here

# Define the chatbot function
def chatbot(query, chat_history=[]):
    global qa_chain, tokenizer, model

    try:
        # Determine if the query is general or company-specific
        company_keywords = ["company", "performance", "ESG risk", "rating", "sector", "employees",
                            "decarbonization", "target", "turnover", "Name", "Ticker", "Sector"]

        if any(keyword.lower() in query.lower() for keyword in company_keywords):
            # Company-specific query, use the retriever
            result = qa_chain.invoke({'question': query, 'chat_history': chat_history})
            answer = result['answer']
        else:
            # General ESG question, use the fine-tuned model directly
            inputs = tokenizer(query, return_tensors="pt").to(model.device)
            outputs = model.generate(**inputs, max_length=512)
            answer = tokenizer.decode(outputs[0], skip_special_tokens=True)

        # Append the question and answer to the chat history
        chat_history.append((query, answer))

        # Prepare the history for display in the Gradio chat interface
        chat_history_display = [(f"User: {q}", f"Bot: {a}") for q, a in chat_history]

        return chat_history_display, chat_history

    except Exception as e:
        return [("Error", f"An error occurred: {str(e)}")], chat_history

# Function to reset the chat history
def reset_chat():
    return [], []

# Function to handle feedback
def give_feedback(feedback, chat_history):
    feedback_log.append((chat_history[-1], feedback))
    print(f"Received feedback: {feedback} for the response: {chat_history[-1]}")
    return "Feedback recorded!"

# Define the Gradio chat interface
with gr.Blocks() as iface:
    gr.Markdown("# ESG Chatbot")

    with gr.Row():
        with gr.Column(scale=3):
            chatbox = gr.Chatbot(label="ESG Chatbot")

            with gr.Row():
                good_feedback = gr.Button("👍 Good")
                bad_feedback = gr.Button("👎 Bad")

        with gr.Column(scale=1):
            textbox = gr.Textbox(label="Type your query here:")
            submit_button = gr.Button("Submit")
            reset_button = gr.Button("Start New Conversation")

    # Function to handle button click and update chatbox
    def on_submit(query, history):
        chat_history_display, updated_history = chatbot(query, history)
        return chat_history_display, updated_history

    # Connect functions to buttons
    submit_button.click(on_submit, inputs=[textbox, chatbox], outputs=[chatbox, chatbox])
    textbox.submit(on_submit, inputs=[textbox, chatbox], outputs=[chatbox, chatbox])
    reset_button.click(reset_chat, outputs=[chatbox, textbox])
    good_feedback.click(lambda history: give_feedback("Good", history), inputs=[chatbox], outputs=None)
    bad_feedback.click(lambda history: give_feedback("Bad", history), inputs=[chatbox], outputs=None)

# Launch the interface
iface.launch()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#    1602         try:
# -> 1603             return importlib.import_module("." + module_name, self.__name__)
#    1604         except Exception as e:
#
# /usr/lib/python3.10/importlib/__init__.py in import_module(name, package)
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _load_unlocked(spec)
#
# ...

# %%
AchrafGhribi31/llama3-esg-8b-merged-4bit_V0

# %%
import gradio as gr
from transformers import pipeline
from unsloth import FastLanguageModel
from langchain.llms import HuggingFacePipeline
from langchain.chains import ConversationalRetrievalChain
from langchain.vectorstores import FAISS
from langchain.embeddings import HuggingFaceEmbeddings
from langchain_community.document_loaders.csv_loader import CSVLoader
from langchain.text_splitter import CharacterTextSplitter
import os

# Set your Hugging Face token in the environment variables
os.environ["HF_TOKEN"] = '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'

# Load your fine-tuned model and tokenizer using Unsloth
model_name = "AchrafGhribi31/llama3-esg-8b-merged-4bit_finalchat"
tokenizer_name = model_name

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name=model_name,
    max_seq_length=1024,
    load_in_4bit=True,
    token=os.environ.get("HF_TOKEN")
)

# Prepare the model for inference
FastLanguageModel.for_inference(model)

# Create the text generation pipeline using your fine-tuned model
text_generation_pipeline = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    eos_token_id=tokenizer.eos_token_id,
    pad_token_id=tokenizer.eos_token_id,
    repetition_penalty=1.2,
    return_full_text=False,
    max_new_tokens=200,
    temperature=0.5,
    do_sample=False,
    top_k=50,
    top_p=0.8
)

# Create the HuggingFacePipeline LLM
fine_tuned_llm = HuggingFacePipeline(pipeline=text_generation_pipeline)

# Load and process the CSV file
dataset_path = '/content/CompaniesDataESG.csv'  # Replace with your actual file path
loader = CSVLoader(file_path=dataset_path)
data = loader.load()

# Split the documents into smaller chunks
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
chunked_docs = text_splitter.split_documents(data)

# Create embeddings and build the FAISS index
embeddings = HuggingFaceEmbeddings(model_name='sentence-transformers/all-mpnet-base-v2')
db = FAISS.from_documents(chunked_docs, embeddings)

# Connect query to FAISS index using a retriever
retriever = db.as_retriever(
    search_type="similarity",
    search_kwargs={'k': 8}  # Increase k for better context in retrieval
)

# Create the Conversational Retrieval Chain
qa_chain = ConversationalRetrievalChain.from_llm(
    llm=fine_tuned_llm,
    retriever=retriever,
    return_source_documents=True
)

# Initialize the chat history
chat_history = []
feedback_log = []

# Define the chatbot function
def chatbot(query, chat_history=[]):
    global qa_chain, tokenizer, model

    try:
        # Determine if the query is general or company-specific
        company_keywords = ["company", "performance", "ESG risk", "rating", "sector", "employees",
                            "decarbonization", "target", "turnover", "Name", "Ticker", "Sector"]

        if any(keyword.lower() in query.lower() for keyword in company_keywords):
            # Company-specific query, use the retriever
            result = qa_chain.invoke({'question': query, 'chat_history': chat_history})
            answer = result['answer']
        else:
            # General ESG question, use the fine-tuned model directly
            inputs = tokenizer(query, return_tensors="pt").to(model.device)
            outputs = model.generate(**inputs, max_length=512)
            answer = tokenizer.decode(outputs[0], skip_special_tokens=True)

        # Append the question and answer to the chat history
        chat_history.append((query, answer))

        # Prepare the history for display in the Gradio chat interface
        chat_history_display = [(f"User: {q}", f"Bot: {a}") for q, a in chat_history]

        return chat_history_display, chat_history

    except Exception as e:
        return [("Error", f"An error occurred: {str(e)}")], chat_history

# Function to reset the chat history
def reset_chat():
    global chat_history
    chat_history = []  # Clear chat history when starting a new conversation
    return [], []

# Function to handle feedback
def give_feedback(feedback, chat_history):
    feedback_log.append((chat_history[-1], feedback))
    print(f"Received feedback: {feedback} for the response: {chat_history[-1]}")
    return "Feedback recorded!"

# Define the Gradio chat interface
with gr.Blocks() as iface:
    gr.Markdown("# ESG Chatbot")

    with gr.Row():
        with gr.Column(scale=3):
            chatbox = gr.Chatbot(label="ESG Chatbot")

            with gr.Row():
                good_feedback = gr.Button("👍 Good")
                bad_feedback = gr.Button("👎 Bad")

        with gr.Column(scale=1):
            textbox = gr.Textbox(label="Type your query here:")
            submit_button = gr.Button("Submit")
            reset_button = gr.Button("Start New Conversation")

    # Function to handle button click and update chatbox
    def on_submit(query, history):
        chat_history_display, updated_history = chatbot(query, history)
        return chat_history_display, updated_history

    # Connect functions to buttons
    submit_button.click(on_submit, inputs=[textbox, chatbox], outputs=[chatbox, chatbox])
    textbox.submit(on_submit, inputs=[textbox, chatbox], outputs=[chatbox, chatbox])
    reset_button.click(reset_chat, outputs=[chatbox, textbox])
    good_feedback.click(lambda history: give_feedback("Good", history), inputs=[chatbox], outputs=None)
    bad_feedback.click(lambda history: give_feedback("Bad", history), inputs=[chatbox], outputs=None)

# Launch the interface
iface.launch()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#    1602         try:
# -> 1603             return importlib.import_module("." + module_name, self.__name__)
#    1604         except Exception as e:
#
# /usr/lib/python3.10/importlib/__init__.py in import_module(name, package)
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.10/importlib/_bootstrap.py in _load_unlocked(spec)
#
# ...
